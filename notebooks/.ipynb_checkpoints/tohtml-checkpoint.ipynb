# %%
import pandas as pd 
import plotly.graph_objects as go
import csv

# %%
# to read csv file 
c = pd.read_csv("../templates/cities.csv") 
df = pd.DataFrame(c)
# to save as html file 
html_file = c.to_html("cities.html") 
html_file

# %%
# Thought of formatting tables in flask
fig = go.Figure(data=[go.Table( header=dict(values=list(df.columns), fill_color='blue',align='left'),
                                cells=dict(values=[df["City"], df["Country"], df["Latitude"], df["Longitude"], df["Date"], 
                                                   df["Cloudiness"], df["Humidity"], df["Max Tempature"], df["Wind Speed"]], fill_color='blue', 
                                                   align='left'))])
fig.show()
# Out:
# <div>                            <div id="faebd9f1-1c34-4d21-9895-8a166a09ac90" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("faebd9f1-1c34-4d21-9895-8a166a09ac90")) {                    Plotly.newPlot(                        "faebd9f1-1c34-4d21-9895-8a166a09ac90",                        [{"cells": {"align": "left", "fill": {"color": "blue"}, "values": [["Kaitangata", "\u2018\u0100huimanu", "Katsuura", "Punta Arenas", "Yellowknife", "Lorengau", "Marsh Harbour", "Marawi", "Rikitea", "Butaritari", "Santo\u00f1a", "Nikolskoye", "New Norfolk", "Albany", "Staritsa", "Faanui", "Jamestown", "Torbay", "Lule\u00e5", "Mataura", "Gushikawa", "Sitka", "Narsaq", "Chapais", "Cabo San Lucas", "Luga", "Ushuaia", "Severo-Kuril'sk", "Poso", "Qaanaaq", "S\u00e3o Fil
# ...
